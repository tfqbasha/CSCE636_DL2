# %% [markdown]
# <a href="https://colab.research.google.com/github/tfqbasha/CSCE636_DL2/blob/master/slowfast_multiclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Go to the Directory
# %cd /content/drive/My\ Drive/Colab\ Notebooks/CSCE636/slowfast-keras2Class/slowfast-keras
# !pip install tensorflow==1.15.0
# !python3 -c 'import tensorflow as tf; print(tf.__version__)'

# %%
#Pre-processing script
# !python utils/ucf_hmdb51_video2jpg.py ../../Data/data_clips2 ../../Data/data_clips2_jpg

#du -sh /content/drive/My\ Drive/Colab\ Notebooks/CSCE636/Data/data_clips
#!ls -lrt /content/drive/My\ Drive/Colab\ Notebooks/CSCE636/Data/data_clips2/*/ | wc -l
from google.colab import drive
drive.flush_and_unmount()

# %%
#frames calculation
# !python utils/ucf_hmdb51_frames.py ../../Data/data_clips2_jpg

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
#!ls -lrt  ../../Data/data_clips2_jpg/opening_present/ | awk '{print $NF}' > ../../Data/data_clips2_jpg/list_opening_present.txt
#!head -n75 ../../Data/data_clips2_jpg/list* > ../../Data/data_clips2_jpg/train.txt

# %% [markdown]
# **TRAIN_CELL**

# %%
import os
import math
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import multi_gpu_model
from model import nets
from model import slowfast
from opts import parse_opts
from utils import get_optimizer, SGDRScheduler_with_WarmUp, TrainPrint, PrintLearningRate, ParallelModelCheckpoint
from dataset.dataset import DataGenerator

class Args:
  root_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/slowfast-keras2Class/slowfast-keras'
  video_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips2_jpg'
  name_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips2_jpg/classInd.txt'
  train_list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips2_jpg/train.txt'
  val_list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips2_jpg/test.txt'
  result_path = 'results_1304'
  data_name = 'ntu'
  gpus = [0]
  log_dir = 'log_0304'
  num_classes = 4
  crop_size = 224
  clip_len = 64
  short_side = [256, 320]
  n_samples_for_each_video = 20
  lr = 0.00001
  momentum = 0.9
  weight_decay = 1e-4
  lr_decay = 0.8
  cycle_length = 10
  multi_factor = 1.5
  warm_up_epoch = 5
  optimizer = 'SGD'
  batch_size = 4
  epochs = 100
  workers = 4
  network = 'resnet50'
  pretrained_weights = None
  #test_videos_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref_test_jpg'
  #test_list_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/test_final.txt'


def create_callbacks(opt, steps_per_epoch, model=None):
    log_dir = os.path.join(opt.root_path, opt.log_dir)
    if not os.path.exists(log_dir):
        os.mkdir(log_dir)
    tensorboard = TensorBoard(log_dir=log_dir, write_graph=True)

    result_path = os.path.join(opt.root_path, opt.result_path)
    if not os.path.exists(result_path):
        os.mkdir(result_path)

    if model is not None:
        print("mbashat: using ParallelModel")
        checkpoint = ParallelModelCheckpoint(model, os.path.join(result_path, '{epoch:03d}.h5'),
                                    monitor='val_acc', save_weights_only=True, save_best_only=True, period=1)
    else:
        print("mbashat: using ModelCheckpoint")
        checkpoint = ModelCheckpoint(os.path.join(result_path, '{epoch:03d}.h5'),
                                    monitor='val_acc', save_weights_only=True, save_best_only=True, period=1)
    early_stopping = EarlyStopping(monitor='val_acc', min_delta=0, patience=10)
    learning_rate_scheduler = SGDRScheduler_with_WarmUp(0, opt.lr, steps_per_epoch, lr_decay=opt.lr_decay, 
                                                        cycle_length=opt.cycle_length, multi_factor=opt.multi_factor,
                                                        warm_up_epoch=opt.warm_up_epoch)
    #training_print = TrainPrint(steps_per_epoch, opt.epochs)
    print_lr = PrintLearningRate()

    return [tensorboard, learning_rate_scheduler, print_lr, checkpoint, early_stopping]
    


def train(opt):
    K.clear_session()
    video_input = Input(shape=(None, None, None, 3))
    model = nets.network[opt.network](video_input, num_classes=opt.num_classes)
    print("Create {} model with {} classes".format(opt.network, opt.num_classes))

    if opt.pretrained_weights is not None:
        model.load_weights(opt.pretrained_weights)
        print("Loading weights from {}".format(opt.pretrained_weights))

    optimizer = get_optimizer(opt)

    train_data_generator = DataGenerator(opt.data_name, opt.video_path, opt.train_list, opt.name_path, 
                                        'train', opt.batch_size, opt.num_classes, True, opt.short_side, 
                                        opt.crop_size, opt.clip_len, opt.n_samples_for_each_video)                                     
    val_data_generator = DataGenerator(opt.data_name, opt.video_path, opt.val_list, opt.name_path, 'val', 
                                        opt.batch_size, opt.num_classes, False, opt.short_side, 
                                        opt.crop_size, opt.clip_len, opt.n_samples_for_each_video)
    #predict_data_generator = DataGenerator(opt.data_name, opt.test_videos_path, opt.test_list_path, opt.name_path, 
     #                                   'val', 1, opt.num_classes, False, opt.short_side, 
      #                                  opt.crop_size, opt.clip_len, opt.n_samples_for_each_video, to_fit=False)  
    
    
    callbacks = create_callbacks(opt, max(1, train_data_generator.__len__()), model)

    if len(opt.gpus) > 1:
        print('Using multi gpus')
        parallel_model = multi_gpu_model(model, gpus=len(opt.gpus))
        parallel_model.compile(optimizer=optimizer, loss=categorical_crossentropy, metrics=['accuracy'])
        parallel_model.fit_generator(train_data_generator, steps_per_epoch=max(1, train_data_generator.__len__()),
                            epochs=opt.epochs, validation_data=val_data_generator, validation_steps=max(1, val_data_generator.__len__()),
                            workers=opt.workers, callbacks=callbacks)
    else:
        print("GPU <1 run")
        model.compile(optimizer=optimizer, loss=categorical_crossentropy, metrics=['accuracy'])
        print("compile done")
        print("mbashat : Val_steps, steps_per_epoch, Val_dat", max(1, val_data_generator.__len__()), max(1, train_data_generator.__len__()), val_data_generator)
        global history_mbt
        #history_mbt = model.fit_generator(train_data_generator, steps_per_epoch=max(1, train_data_generator.__len__()),
                            #epochs=opt.epochs, validation_data=val_data_generator, validation_steps=max(1, val_data_generator.__len__()),
                            #workers=opt.workers, callbacks=callbacks)
        history_mbt = model.fit_generator(train_data_generator, steps_per_epoch=max(1, train_data_generator.__len__()), epochs=opt.epochs, validation_data=val_data_generator, validation_steps=max(1, val_data_generator.__len__()),
                        workers=opt.workers)
        
        #model.summary()
        from tensorflow.keras.utils import plot_model
        plot_model(model, to_file='model.png', show_shapes=True)
    print("model fit done")
    print("mbashat: saving model")
    model.save('SlowFast_refrigerator_1304.h5')
    #print("mbashat: saving weights at :", os.path.join(os.path.join(opt.root_path, opt.result_path) ))
    #model.save_weights(os.path.join(os.path.join(opt.root_path, opt.result_path), 'trained_weights_final_200.h5'))
    #print("mbashat: predict on val data")
    #model_predicted = model.predict(predict_data_generator)
    #import numpy as np
    #print(np.argmax(model_predicted, axis=1))
    #print("mbashat: saving weights to variable")
    #for layer in model.layers:
      #weights = layer.get_weights()
      #print(weights)
    #for video_batch, labels_batch in train_data_generator:
      #print('video batch shape, label shape:', video_batch.shape, labels_batch)
    print('printking Keys in history')
    for key in history_mbt.history:
      print(key)
    # %matplotlib inline
    import matplotlib.pyplot as plt
    acc = history_mbt.history['acc']
    val_acc = history_mbt.history['val_acc']
    loss = history_mbt.history['loss']
    val_loss = history_mbt.history['val_loss']
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'g', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'g', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()
    print("end of code")

if __name__=="__main__":
    opt = Args()
    print(opt)
    if len(opt.gpus) > 1:
        os.environ['CUDA_VISIBLE_DEVICES'] = ",".join(map(str, opt.gpus))
    train(opt)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# <__main__.Args object at 0x7f441c448400>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Create resnet50 model with 4 classes
# ck1
# ck1 : in
# ck2: into get_ucf101
# opening_refrigerator
# {'opening_refrigerator': 0}
# opening_door
# {'opening_refrigerator': 0, 'opening_door': 1}
# opening_bottle_(not_wine)
# {'opening_refrigerator': 0, 'opening_door': 1, 'opening_bottle_(not_wine)': 2}
# opening_present
# {'opening_refrigerator': 0, 'opening_door': 1, 'opening_bottle_(not_wine)': 2, 'opening_present': 3}
# path_label_split: ['opening_bottle_(not_wine)/06QJB3EBIms_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/05gxLjelg1Q_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/260wVERGd08_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/161T0kEGI1I_000038_000048.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/15mynloL3pI_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/11WfYWXFS9M_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/21fe3FnKUnM_000005_000015.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/1WJfpZG-0PQ_000037_000047.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/1r3vZxx56Wk_000004_000014.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/1QYCGc9cHRk_000066_000076.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2PNjFVh5It0_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2qwFgWhSXU8_000004_000014.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2UqK9U0Mks4_000007_000017.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/1uu2C4aUl7Y_000007_000017.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2vvreYTGaT0_000006_000016.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/3BdbHEPL-3g_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2Wi4roT2Tyw_000057_000067.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2xxWWcZNUJk_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2wfbvESWjqE_000003_000013.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2W6YvnHFhmo_000002_000012.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/3H5Acf4SVOQ_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/3lPpEZn8_uc_000002_000012.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/3E1B35yQzAg_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/1XL484jnHEY_000003_000013.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2aTlFqJSbys_000094_000104.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/3OxDeqBJqGk_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2LOaa3ap550_000012_000022.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4dPfU4xcjVw_000002_000012.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4nuPcQ20Ktw_000002_000012.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4KKbWXFw9dc_000022_000032.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/52FyeV-FLxY_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4kTFJXq8894_000046_000056.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4YsK-ibEprs_000001_000011.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/52DSAS-FjRQ_000040_000050.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4NEV7g9ohxs_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4HwOnFF6_l4_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/4NkjMvYzPrI_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2vm7BWA7v9E_000001_000011.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2pUEh0Ku9LA_000008_000018.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/5diEbKIf-u4_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/2yMuhN1h3OQ_000036_000046.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/6BIg3-6RSMI_000093_000103.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/5u3uqs1hzUw_000068_000078.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/32Zv-f_GsVs_000004_000014.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/6cEwDusUC4c_000201_000211.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/5Fd3N5eMseM_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/5kN0x2zekvw_000002_000012.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/5xk6mD1EI6I_000034_000044.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/5CynrB63mqU_000057_000067.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)
000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/jK5efAAW-kA_000003_000013.mp4', 'opening_door']
# path_label_split: ['opening_door/JHMah75GQsY_000009_000019.mp4', 'opening_door']
# path_label_split: ['opening_door/JfWcEjA_6JY_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/JFkMT9JxdvY_000003_000013.mp4', 'opening_door']
# path_label_split: ['opening_door/j_e32zeRCL4_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/jbnJv9KJT3k_000010_000020.mp4', 'opening_door']
# path_label_split: ['opening_door/J6ZS01uC1QI_000046_000056.mp4', 'opening_door']
# path_label_split: ['opening_door/j2muJJjaif8_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/IVL0I_LsyWM_000001_000011.mp4', 'opening_door']
# path_label_split: ['opening_door/irvagS2Dtso_000013_000023.mp4', 'opening_door']
# path_label_split: ['opening_door/h5wU0MZF28Q_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/H0tYfx8T-Dg_000040_000050.mp4', 'opening_door']
# path_label_split: ['opening_door/gyqq0W_OtFc_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/GkSG54iXY-g_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/gJszGKIvSwA_000038_000048.mp4', 'opening_door']
# path_label_split: ['opening_door/GhT7n4T0zA4_000056_000066.mp4', 'opening_door']
# path_label_split: ['opening_door/GfXUBIMCqtk_000029_000039.mp4', 'opening_door']
# path_label_split: ['opening_door/gffjCqUQEUY_000057_000067.mp4', 'opening_door']
# path_label_split: ['opening_door/gdOJaAJfqwI_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/gdLy1Gbpwls_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/GaTri0fM-4k_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/g66tOA5zZqo_000033_000043.mp4', 'opening_door']
# path_label_split: ['opening_door/G5XKvcmM9NM_000007_000017.mp4', 'opening_door']
# path_label_split: ['opening_door/fz8vEPESxCs_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/FRq_-sS5EvM_000001_000011.mp4', 'opening_door']
# path_label_split: ['opening_door/fq0jz8QFYPI_000027_000037.mp4', 'opening_door']
# path_label_split: ['opening_door/FOTvBfamdjE_000005_000015.mp4', 'opening_door']
# path_label_split: ['opening_door/FoCGt0aIukQ_000018_000028.mp4', 'opening_door']
# path_label_split: ['opening_door/FjLuzOXX8Ck_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/FJJ-PiVtw3A_000182_000192.mp4', 'opening_door']
# path_label_split: ['opening_door/Fi3uyWteqhA_000008_000018.mp4', 'opening_door']
# path_label_split: ['opening_door/2y9PaMzMGHw_000011_000021.mp4', 'opening_door']
# path_label_split: ['opening_door/2W2STMjkVuE_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/1WmqD1Te_u4_000032_000042.mp4', 'opening_door']
# path_label_split: ['opening_door/zoFb07FhwuQ_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/ZNcXe9HVNuQ_000006_000016.mp4', 'opening_door']
# path_label_split: ['opening_door/zgGuDLeGpSA_000007_000017.mp4', 'opening_door']
# path_label_split: ['opening_door/z9VpMnbouWs_000001_000011.mp4', 'opening_door']
# path_label_split: ['opening_door/Z8GGSeKCnas_000004_000014.mp4', 'opening_door']
# path_label_split: ['opening_present/wEJAmzZSMkY_000471_000481.mp4', 'opening_present']
# path_label_split: ['opening_present/WCsra7o1Ke8_000036_000046.mp4', 'opening_present']
# path_label_split: ['opening_present/w0NUstCMsmY_000051_000061.mp4', 'opening_present']
# path_label_split: ['opening_present/wfe5CJfbj2A_000007_000017.mp4', 'opening_present']
# path_label_split: ['opening_present/wEevw95f6Wc_000011_000021.mp4', 'opening_present']
# path_label_split: ['opening_present/W5RKb8VwBBI_000079_000089.mp4', 'opening_present']
# path_label_split: ['opening_present/WFdNcz_y1Sc_000027_000037.mp4', 'opening_present']
# path_label_split: ['opening_present/W7szkMVAutk_000022_000032.mp4', 'opening_present']
# path_label_split: ['opening_present/w7Ev-AIOjU8_000017_000027.mp4', 'opening_present']
# path_label_split: ['opening_present/W5gLrp7ahp8_000137_000147.mp4', 'opening_present']
# path_label_split: ['opening_present/WjWqUhvgZLg_000054_000064.mp4', 'opening_present']
# path_label_split: ['opening_present/WRdar7NS5Yc_000003_000013.mp4', 'opening_present']
# path_label_split: ['opening_present/wSAz5Ntau2A_000092_000102.mp4', 'opening_present']
# path_label_split: ['opening_present/wkFabA6tYSk_000006_000016.mp4', 'opening_present']
# path_label_split: ['opening_present/wKfYPf0viQc_000013_000023.mp4', 'opening_present']
# path_label_split: ['opening_present/WpLuvrUl0zE_000069_000079.mp4', 'opening_present']
# path_label_split: ['opening_present/wjZYZ2aTriA_000035_000045.mp4', 'opening_present']
# path_label_split: ['opening_present/X0omCR6ujm0_000010_000020.mp4', 'opening_present']
# path_label_split: ['opening_present/x03FAaEUTaM_000031_000041.mp4', 'opening_present']
# path_label_split: ['opening_present/wNOjcoFPDg0_000002_000012.mp4', 'opening_present']
# path_label_split: ['opening_present/X36sQ9_rbV8_000096_000106.mp4', 'opening_present']
# path_label_split: ['opening_present/XaVXRXXte94_000031_000041.mp4', 'opening_present']
# path_label_split: ['opening_present/XDabOKlANGc_000236_000246.mp4', 'opening_present']
# path_label_split: ['opening_present/x4UYzKG2SAY_000005_000015.mp4', 'opening_present']
# path_label_split: ['opening_present/Xh3Pq2il17E_000026_000036.mp4', 'opening_present']
# path_label_split: ['opening_present/XeihxJfnhqM_000081_000091.mp4', 'opening_present']
# path_label_split: ['opening_present/xE1O-fO8tMA_000026_000036.mp4', 'opening_present']
# path_label_split: ['opening_present/x5fg719o7uQ_000196_000206.mp4', 'opening_present']
# path_label_split: ['opening_present/YKdjkMjlztU_000023_000033.mp4', 'opening_present']
# path_label_split: ['opening_present/ydgMVix6hBU_000030_000040.mp4', 'opening_present']
# path_label_split: ['opening_present/xWhjUQdyNmk_000054_000064.mp4', 'opening_present']
# path_label_split: ['opening_present/XIh6kRVaCSo_000000_000010.mp4', 'opening_present']
# path_label_split: ['opening_present/XhnlW42opdg_000086_000096.mp4', 'opening_present']
# path_label_split: ['opening_present/XF-jJ2RCpYo_000070_000080.mp4', 'opening_present']
# path_label_split: ['opening_present/yeN3owP1jgU_000000_000010.mp4', 'opening_present']
# path_label_split: ['opening_present/Y4-6exbdGPo_000431_000441.mp4', 'opening_present']
# path_label_split: ['opening_present/Xx76Lowhvp8_000179_000189.mp4', 'opening_present']
# path_label_split: ['opening_present/Y0HhbOY3dv0_000002_000012.mp4', 'opening_present']
# path_label_split: ['opening_present/XVcrlanV-W4_000034_000044.mp4', 'opening_present']
# path_label_split: ['opening_present/XO8Qdwt06hI_000009_000019.mp4', 'opening_present']
# path_label_split: ['opening_present/Z9kB0U4TXPQ_000037_000047.mp4', 'opening_present']
# path_label_split: ['opening_present/YosyPuwaU-M_000033_000043.mp4', 'opening_present']
# path_label_split: ['opening_present/yNPSfMb4vKo_000008_000018.mp4', 'opening_present']
# path_label_split: ['opening_present/z4C-oTtrj2Y_000039_000049.mp4', 'opening_present']
# path_label_split: ['opening_present/YOzRgawJRs4_000040_000050.mp4', 'opening_present']
# path_label_split: ['opening_present/YonHYBoanx0_000009_000019.mp4', 'opening_present']
# path_label_split: ['opening_present/yoIk7s3az5w_000026_000036.mp4', 'opening_present']
# path_label_split: ['opening_present/ZyDUU6REglI_000000_000010.mp4', 'opening_present']
# path_label_split: ['opening_present/ZeaVpF0Y5QI_000004_000014.mp4', 'opening_present']
# path_label_split: ['opening_present/ZBUjEKt8ygo_000035_000045.mp4', 'opening_present']
# path_label_split: ['opening_present/zAe0Y0-ILjY_000091_000101.mp4', 'opening_present']
# path_label_split: ['opening_present/z4ZXSxTa5hM_000026_000036.mp4', 'opening_present']
# path_label_split: ['opening_present/zXqEc29jTIE_000052_000062.mp4', 'opening_present']
# path_label_split: ['opening_present/zxLrqYnXE8Y_000065_000075.mp4', 'opening_present']
# path_label_split: ['opening_present/Zung4qq95bA_000004_000014.mp4', 'opening_present']
# path_label_split: ['opening_present/zT5K7mixi3E_000085_000095.mp4', 'opening_present']
# path_label_split: ['opening_present/ZpqlrPGsNAQ_000019_000029.mp4', 'opening_present']
# path_label_split: ['opening_present/zegohrV5Pag_000134_000144.mp4', 'opening_present']
# path_label_split: ['opening_present/MXdCiNVs8dU_000000_000010.mp4', 'opening_present']
# path_label_split: ['opening_present/mdZ5YpvxATg_000260_000270.mp4', 'opening_present']
# path_label_split: ['opening_present/mD58Uy0aioE_000882_000892.mp4', 'opening_present']
# path_label_split: ['opening_present/Mcz0pmumnfI_000129_000139.mp4', 'opening_present']
# path_label_split: ['opening_present/N-WulhymneM_000037_000047.mp4', 'opening_present']
# path_label_split: ['opening_present/Nc4GC6WAo2c_000011_000021.mp4', 'opening_present']
# path_label_split: ['opening_present/N2zC9c5f_Ro_001908_001918.mp4', 'opening_present']
# path_label_split: ['opening_present/n2JvjlD2KO0_000017_000027.mp4', 'opening_present']
# path_label_split: ['opening_present/n1moXwqrQrU_000146_000156.mp4', 'opening_present']
# path_label_split: ['opening_present/OAvU9wPQ_0c_000205_000215.mp4', 'opening_present']
# path_label_split: ['opening_present/o-As9B-O4a0_000000_000010.mp4', 'opening_present']
# path_label_split: ['opening_present/O7LtlPaAa1g_000002_000012.mp4', 'opening_present']
# path_label_split: ['opening_present/o2GR1wGNt5g_000256_000266.mp4', 'opening_present']
# path_label_split: ['opening_present/ngxUi-LOSoE_000029_000039.mp4', 'opening_present']
# path_label_split: ['opening_present/NFUkBur2uPs_000088_000098.mp4', 'opening_present']
# path_label_split: ['opening_present/negqEtTQOHQ_000049_000059.mp4', 'opening_present']
# path_label_split: ['opening_present/oDQyjTN0-VY_000027_000037.mp4', 'opening_present']
# path_label_split: ['opening_refrigerator/U614b3e_C5w_000020_000030.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator
mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/t0C9sPwW9lM_000065_000075.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/StE5hjjVcDY_000226_000236.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/SrzPuu_K-vw_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/UglsBVnxEyg_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/uEiriYyoGkI_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/tJx5VXf-ub8_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/tD0suxbRJPo_000003_000013.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/tafbsraXczM_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/WELx2Vd1sJQ_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/WeKddS2DhdE_000011_000021.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/WCtL3QDdPO8_000015_000025.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/UrGa1hiDPiM_000023_000033.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/UHG7foc8WJE_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/Yc5TigyUPJI_000139_000149.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/xx02045Ko2s_000133_000143.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/xL3syUexgr4_000004_000014.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/XeweHSPJgE4_000003_000013.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/xc4B2CBlSdA_000000_000010.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_bottle_(not_wine)/zLca7QenJQo_000004_000014.mp4', 'opening_bottle_(not_wine)']
# path_label_split: ['opening_door/384mDE1V9xI_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/2sp07Qi4LcA_000053_000063.mp4', 'opening_door']
# path_label_split: ['opening_door/2nggCWcnczs_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/2GqaJlM0qE8_000083_000093.mp4', 'opening_door']
# path_label_split: ['opening_door/2EyIyJ0niv8_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/2akv-xk48xc_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/26ywvh5BXuE_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/20WrKOA_nc8_000027_000037.mp4', 'opening_door']
# path_label_split: ['opening_door/1X0WDA4ZqME_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/1hmTyt3BIXs_000036_000046.mp4', 'opening_door']
# path_label_split: ['opening_door/1fC289V-HYs_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/1cTFOPPvkic_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/1b16i2iqxio_000002_000012.mp4', 'opening_door']
# path_label_split: ['opening_door/0YV3lTQFszM_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/0wJnRRiewjs_000129_000139.mp4', 'opening_door']
# path_label_split: ['opening_door/0oy82plJmZg_000008_000018.mp4', 'opening_door']
# path_label_split: ['opening_door/-0oOhwW5i8I_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/0LUXOem6FFs_000012_000022.mp4', 'opening_door']
# path_label_split: ['opening_door/0Cx8ZEQIyl4_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_door/04oZPET_eRQ_000000_000010.mp4', 'opening_door']
# path_label_split: ['opening_present/vcBEL-qxfKU_000099_000109.mp4', 'opening_present']
# path_label_split: ['opening_present/VpzhscntW9o_000116_000126.mp4', 'opening_present']
# path_label_split: ['opening_present/VMaVZ1JJX2w_000032_000042.mp4', 'opening_present']
# path_label_split: ['opening_present/vk5VA13keEk_000003_000013.mp4', 'opening_present']
# path_label_split: ['opening_present/vH9flo4Upcg_000038_000048.mp4', 'opening_present']
# path_label_split: ['opening_present/w47-l71br8c_000188_000198.mp4', 'opening_present']
# path_label_split: ['opening_present/W38E_r9nUto_000060_000070.mp4', 'opening_present']
# path_label_split: ['opening_present/w0yc-uoSxFs_000201_000211.mp4', 'opening_present']
# path_label_split: ['opening_present/vrTv_CV4XKY_000125_000135.mp4', 'opening_present']
# path_label_split: ['opening_present/WedxrG3cw8o_001272_001282.mp4', 'opening_present']
# path_label_split: ['opening_present/wctxTtsSlPo_000026_000036.mp4', 'opening_present']
# path_label_split: ['opening_present/WCkmTTwinMU_000021_000031.mp4', 'opening_present']
# path_label_split: ['opening_present/W6DPjID0G0E_000097_000107.mp4', 'opening_present']
# path_label_split: ['opening_present/w5AOsUvYLqY_000020_000030.mp4', 'opening_present']
# path_label_split: ['opening_present/wo1rd00BuhE_000014_000024.mp4', 'opening_present']
# path_label_split: ['opening_present/WKy53B4V1dE_000017_000027.mp4', 'opening_present']
# path_label_split: ['opening_present/wJE0i6LtWsk_000023_000033.mp4', 'opening_present']
# path_label_split: ['opening_present/wezJHDBFFRg_000069_000079.mp4', 'opening_present']
# path_label_split: ['opening_present/wejfro9LWtk_000095_000105.mp4', 'opening_present']
# path_label_split: ['opening_present/woodZvZis6c_000177_000187.mp4', 'opening_present']
# path_label_split: ['opening_refrigerator/3LYxXHvXPlY_000013_000023.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/3JVrNN6xCyA_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/3duuaAbhLcA_000525_000535.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/3ci9kJae94Q_000186_000196.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/36yg4k3S1tQ_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/2rpwY1-H9f8_000075_000085.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/2ap4Usb1vwE_000007_000017.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/28IUkYrLgzo_000093_000103.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/249ai1NIC4c_000042_000052.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/234xg4Ac5PU_000010_000020.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/1tAO1Sq5Peg_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/1Q2PX-Mz7kY_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/1nqIFqrv4hE_000013_000023.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/1ggf8xmN0N8_000049_000059.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/1bTHEcbW04Q_000155_000165.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0_X1oD9F5Os_000004_000014.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0VMAS_YISpk_000033_000043.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0ORnm6UF0XU_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0i77oLVaxZY_000031_000041.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0DOPEMDlGok_000042_000052.mp4', 'opening_refrigerator']
# ck3
# dataset loading [0/80]
# mbashat: using ParallelModel
# GPU <1 run
# compile done
# mbashat : Val_steps, steps_per_epoch, Val_dat 20 75 <dataset.dataset.DataGenerator object at 0x7f43c5b46c18>
# Epoch 1/100
# 74/75 [============================>.] - ETA: 24s - loss: 2.2641 - acc: 0.2568Epoch 1/100
# 75/75 [==============================] - 2018s 27s/step - loss: 2.2614 - acc: 0.2567 - val_loss: 1.3971 - val_acc: 0.0000e+00
# Epoch 2/100
# 74/75 [============================>.] - ETA: 15s - loss: 1.9212 - acc: 0.2635Epoch 1/100
# 75/75 [==============================] - 1173s 16s/step - loss: 1.9226 - acc: 0.2633 - val_loss: 1.5004 - val_acc: 0.0000e+00
# Epoch 3/100
# 74/75 [============================>.] - ETA: 13s - loss: 2.1002 - acc: 0.2264Epoch 1/100
# 75/75 [==============================] - 1014s 14s/step - loss: 2.1074 - acc: 0.2233 - val_loss: 1.6037 - val_acc: 0.0000e+00
# Epoch 4/100
# 74/75 [============================>.] - ETA: 12s - loss: 1.8928 - acc: 0.2872Epoch 1/100
# 75/75 [==============================] - 942s 13s/step - loss: 1.8903 - acc: 0.2867 - val_loss: 1.8378 - val_acc: 0.0000e+00
# Epoch 5/100
# 74/75 [============================>.] - ETA: 10s - loss: 1.8302 - acc: 0.3243Epoch 1/100
# 75/75 [==============================] - 824s 11s/step - loss: 1.8368 - acc: 0.3200 - val_loss: 1.7884 - val_acc: 0.0000e+00
# Epoch 6/100
# 74/75 [============================>.] - ETA: 7s - loss: 1.9686 - acc: 0.2736 Epoch 1/100
# 75/75 [==============================] - 545s 7s/step - loss: 1.9696 - acc: 0.2733 - val_loss: 1.3110 - val_acc: 0.2875
100
# 74/75 [============================>.] - ETA: 0s - loss: 1.7218 - acc: 0.3041Epoch 1/100
# 75/75 [==============================] - 93s 1s/step - loss: 1.7180 - acc: 0.3067 - val_loss: 1.4798 - val_acc: 0.0625
# Epoch 94/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.7363 - acc: 0.2770Epoch 1/100
# 75/75 [==============================] - 93s 1s/step - loss: 1.7400 - acc: 0.2733 - val_loss: 1.5936 - val_acc: 0.0000e+00
# Epoch 95/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.8181 - acc: 0.2669Epoch 1/100
# 75/75 [==============================] - 93s 1s/step - loss: 1.8208 - acc: 0.2633 - val_loss: 1.4822 - val_acc: 0.0125
# Epoch 96/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.8634 - acc: 0.2736Epoch 1/100
# 75/75 [==============================] - 93s 1s/step - loss: 1.8596 - acc: 0.2767 - val_loss: 1.4432 - val_acc: 0.0000e+00
# Epoch 97/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.8305 - acc: 0.2973Epoch 1/100
# 75/75 [==============================] - 93s 1s/step - loss: 1.8198 - acc: 0.3000 - val_loss: 1.6593 - val_acc: 0.0625
# Epoch 98/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.8274 - acc: 0.2804Epoch 1/100
# 75/75 [==============================] - 93s 1s/step - loss: 1.8358 - acc: 0.2767 - val_loss: 1.5788 - val_acc: 0.0875
# Epoch 99/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.7306 - acc: 0.2669Epoch 1/100
# 75/75 [==============================] - 92s 1s/step - loss: 1.7442 - acc: 0.2633 - val_loss: 1.6755 - val_acc: 0.0000e+00
# Epoch 100/100
# 74/75 [============================>.] - ETA: 0s - loss: 1.7257 - acc: 0.3007Epoch 1/100
# 75/75 [==============================] - 94s 1s/step - loss: 1.7254 - acc: 0.3000 - val_loss: 1.4919 - val_acc: 0.1125
# model fit done
# mbashat: saving model
# printking Keys in history
# loss
# acc
# val_loss
# val_acc
# end of code

# %% [markdown]
# **TEST_CELL**

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import multi_gpu_model
from model import nets
from model import slowfast
from opts import parse_opts
from utils import get_optimizer, SGDRScheduler_with_WarmUp, TrainPrint, PrintLearningRate, ParallelModelCheckpoint
from dataset.dataset import DataGenerator
from tensorflow.keras.layers import Layer, InputSpec
#from tensorflow.python.keras.layers import Layer, InputSpec
class Args:
  root_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/slowfast-keras2Class/slowfast-keras'
  video_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref_jpg'
  #name_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/classInd.txt'
  name_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_2class_jpg/classInd.txt'
  train_list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/train.txt'
  val_list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/test.txt'
  result_path = 'results'
  data_name = 'ntu'
  gpus = [0]
  log_dir = 'log'
  num_classes = 2
  crop_size = 224
  clip_len = 64
  short_side = [256, 320]
  n_samples_for_each_video = 1
  lr = 0.00001
  momentum = 0.9
  weight_decay = 1e-4
  lr_decay = 0.8
  cycle_length = 10
  multi_factor = 1.5
  warm_up_epoch = 5
  optimizer = 'SGD'
  batch_size = 1
  epochs = 30
  workers = 4
  network = 'resnet50'
  pretrained_weights = None
  #test_videos_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref_jpg'
  #test_list_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/test_final.txt'
  test_videos_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_2class_jpg'
  test_list_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_2class_jpg/train_new.txt'
opt = Args()
# load model
model =  tf.keras.models.load_model('SlowFast_refrigerator_0204.h5')
# summarize model.
#model.summary()
predict_data_generator = DataGenerator(opt.data_name, opt.test_videos_path, opt.test_list_path, opt.name_path, 
                                        'val', 1, opt.num_classes, False, opt.short_side, 
                                        opt.crop_size, opt.clip_len, opt.n_samples_for_each_video, to_fit=False)  
model_predicted = model.predict(predict_data_generator)
import numpy as np
print(np.argmax(model_predicted, axis=1))
