list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_2class_jpg/test_new.txt'
  result_path = 'results_2803'
  data_name = 'ntu'
  gpus = [0]
  log_dir = 'log_2803'
  num_classes = 2
  crop_size = 224
  clip_len = 64
  short_side = [256, 320]
  n_samples_for_each_video = 1
  lr = 0.00001
  momentum = 0.9
  weight_decay = 1e-4
  lr_decay = 0.8
  cycle_length = 10
  multi_factor = 1.5
  warm_up_epoch = 5
  optimizer = 'SGD'
  batch_size = 10
  epochs = 30
  workers = 4
  network = 'resnet50'
  pretrained_weights = None
  #test_videos_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref_test_jpg'
  #test_list_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/test_final.txt'


def create_callbacks(opt, steps_per_epoch, model=None):
    log_dir = os.path.join(opt.root_path, opt.log_dir)
    if not os.path.exists(log_dir):
        os.mkdir(log_dir)
    tensorboard = TensorBoard(log_dir=log_dir, write_graph=True)

    result_path = os.path.join(opt.root_path, opt.result_path)
    if not os.path.exists(result_path):
        os.mkdir(result_path)

    if model is not None:
        print("mbashat: using ParallelModel")
        checkpoint = ParallelModelCheckpoint(model, os.path.join(result_path, '{epoch:03d}.h5'),
                                    monitor='val_acc', save_weights_only=True, save_best_only=True, period=1)
    else:
        print("mbashat: using ModelCheckpoint")
        checkpoint = ModelCheckpoint(os.path.join(result_path, '{epoch:03d}.h5'),
                                    monitor='val_acc', save_weights_only=True, save_best_only=True, period=1)
    early_stopping = EarlyStopping(monitor='val_acc', min_delta=0, patience=10)
    learning_rate_scheduler = SGDRScheduler_with_WarmUp(0, opt.lr, steps_per_epoch, lr_decay=opt.lr_decay, 
                                                        cycle_length=opt.cycle_length, multi_factor=opt.multi_factor,
                                                        warm_up_epoch=opt.warm_up_epoch)
    #training_print = TrainPrint(steps_per_epoch, opt.epochs)
    print_lr = PrintLearningRate()

    return [tensorboard, learning_rate_scheduler, print_lr, checkpoint, early_stopping]
    


def train(opt):
    K.clear_session()
    video_input = Input(shape=(None, None, None, 3))
    model = nets.network[opt.network](video_input, num_classes=opt.num_classes)
    print("Create {} model with {} classes".format(opt.network, opt.num_classes))

    if opt.pretrained_weights is not None:
        model.load_weights(opt.pretrained_weights)
        print("Loading weights from {}".format(opt.pretrained_weights))

    optimizer = get_optimizer(opt)

    train_data_generator = DataGenerator(opt.data_name, opt.video_path, opt.train_list, opt.name_path, 
                                        'train', opt.batch_size, opt.num_classes, True, opt.short_side, 
                                        opt.crop_size, opt.clip_len, opt.n_samples_for_each_video)                                     
    val_data_generator = DataGenerator(opt.data_name, opt.video_path, opt.val_list, opt.name_path, 'val', 
                                        opt.batch_size, opt.num_classes, False, opt.short_side, 
                                        opt.crop_size, opt.clip_len, opt.n_samples_for_each_video)
    #predict_data_generator = DataGenerator(opt.data_name, opt.test_videos_path, opt.test_list_path, opt.name_path, 
     #                                   'val', 1, opt.num_classes, False, opt.short_side, 
      #                                  opt.crop_size, opt.clip_len, opt.n_samples_for_each_video, to_fit=False)  
    
    
    callbacks = create_callbacks(opt, max(1, train_data_generator.__len__()), model)

    if len(opt.gpus) > 1:
        print('Using multi gpus')
        parallel_model = multi_gpu_model(model, gpus=len(opt.gpus))
        parallel_model.compile(optimizer=optimizer, loss=categorical_crossentropy, metrics=['accuracy'])
        parallel_model.fit_generator(train_data_generator, steps_per_epoch=max(1, train_data_generator.__len__()),
                            epochs=opt.epochs, validation_data=val_data_generator, validation_steps=max(1, val_data_generator.__len__()),
                            workers=opt.workers, callbacks=callbacks)
    else:
        print("GPU <1 run")
        model.compile(optimizer=optimizer, loss=categorical_crossentropy, metrics=['accuracy'])
        print("compile done")
        print("mbashat : Val_steps, steps_per_epoch, Val_dat", max(1, val_data_generator.__len__()), max(1, train_data_generator.__len__()), val_data_generator)
        global history_mbt
        #history_mbt = model.fit_generator(train_data_generator, steps_per_epoch=max(1, train_data_generator.__len__()),
                            #epochs=opt.epochs, validation_data=val_data_generator, validation_steps=max(1, val_data_generator.__len__()),
                            #workers=opt.workers, callbacks=callbacks)
        history_mbt = model.fit_generator(train_data_generator, steps_per_epoch=max(1, train_data_generator.__len__()), epochs=opt.epochs, validation_data=val_data_generator, validation_steps=max(1, val_data_generator.__len__()),
                        workers=opt.workers)
        
        #model.summary()
        from tensorflow.keras.utils import plot_model
        plot_model(model, to_file='model.png', show_shapes=True)
    print("model fit done")
    print("mbashat: saving model")
    model.save('SlowFast_refrigerator_2803.h5')
    #print("mbashat: saving weights at :", os.path.join(os.path.join(opt.root_path, opt.result_path) ))
    #model.save_weights(os.path.join(os.path.join(opt.root_path, opt.result_path), 'trained_weights_final_200.h5'))
    #print("mbashat: predict on val data")
    #model_predicted = model.predict(predict_data_generator)
    #import numpy as np
    #print(np.argmax(model_predicted, axis=1))
    #print("mbashat: saving weights to variable")
    #for layer in model.layers:
      #weights = layer.get_weights()
      #print(weights)
    #for video_batch, labels_batch in train_data_generator:
      #print('video batch shape, label shape:', video_batch.shape, labels_batch)
    print('printking Keys in history')
    for key in history_mbt.history:
      print(key)
    # %matplotlib inline
    import matplotlib.pyplot as plt
    acc = history_mbt.history['acc']
    val_acc = history_mbt.history['val_acc']
    loss = history_mbt.history['loss']
    val_loss = history_mbt.history['val_loss']
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'g', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'g', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()
    print("end of code")

if __name__=="__main__":
    opt = Args()
    print(opt)
    if len(opt.gpus) > 1:
        os.environ['CUDA_VISIBLE_DEVICES'] = ",".join(map(str, opt.gpus))
    train(opt)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will switch to TensorFlow 2.x on the 27th of March, 2020.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# <__main__.Args object at 0x7f85bbc2e1d0>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Create resnet50 model with 2 classes
# ck1
# ck1 : in
# ck2: into get_ucf101
# opening_refrigerator
# {'opening_refrigerator': 0}
# other_classes
# {'opening_refrigerator': 0, 'other_classes': 1}
# path_label_split: ['opening_refrigerator/0DOPEMDlGok_000042_000052.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0gK5754h_gI_000023_000033.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0i77oLVaxZY_000031_000041.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0ORnm6UF0XU_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0OsoFM9WR0c_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0pDKU8A3nPA_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/0_X1oD9F5Os_000004_000014.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/_9_nFPaaxMo_000002_000012.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/-AgaSBY0Aok_000004_000014.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/_cDF-Y9dSd0_000047_000057.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/-FLHSwGuHBs_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/-gjX-9clI_M_000025_000035.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/_HhK9U_V1Nw_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/-Lf1JVbumdw_000032_000042.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Li_JW4NQCRc_000015_000025.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator
000007_000017.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/sG09lcUKuMg_000002_000012.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/SH1hbL43JBw_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/SH51xpWGBRk_000005_000015.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/SIJbe0IcY8A_000008_000018.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Sjvp23-dC8E_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/skrBpK-C4A8_000002_000012.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Sniuk64SGvg_000004_000014.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/sOwh5PZiS88_000051_000061.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/S_rYAKxAqBU_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ssJp6uUqU8Y_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/SwBYJI46aB4_000017_000027.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/szyy-X-Rznw_000003_000013.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/tc6qGapJmog_000019_000029.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/TDBBNf-ZrPg_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['other_classes/00ez-cef3-0_000032_000042.mp4', 'other_classes']
# path_label_split: ['other_classes/01rdh-3CnsE_000013_000023.mp4', 'other_classes']
# path_label_split: ['other_classes/03YDz6dM2lc_000020_000030.mp4', 'other_classes']
# path_label_split: ['other_classes/049saZEnyvw_000025_000035.mp4', 'other_classes']
# path_label_split: ['other_classes/04oZPET_eRQ_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/05gxLjelg1Q_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/06PPsi_fbhc_000047_000057.mp4', 'other_classes']
# path_label_split: ['other_classes/06QJB3EBIms_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/-06S_2g51gY_000008_000018.mp4', 'other_classes']
# path_label_split: ['other_classes/0A1_c7pGgFc_000024_000034.mp4', 'other_classes']
# path_label_split: ['other_classes/0A8qsqdGy9g_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0apRjOL0cBM_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0asrQ8zP_nQ_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0asSrS283cQ_000097_000107.mp4', 'other_classes']
# path_label_split: ['other_classes/0cdXCWf5CDY_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0cRYsT9pHOM_000051_000061.mp4', 'other_classes']
# path_label_split: ['other_classes/0Cx8ZEQIyl4_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0ECsvazS25g_000002_000012.mp4', 'other_classes']
# path_label_split: ['other_classes/0epZVCrKG0I_000252_000262.mp4', 'other_classes']
# path_label_split: ['other_classes/0foVlayF72U_000006_000016.mp4', 'other_classes']
# path_label_split: ['other_classes/0foWkOFyYG0_000068_000078.mp4', 'other_classes']
# path_label_split: ['other_classes/_0Hem_Ny2d8_000004_000014.mp4', 'other_classes']
# path_label_split: ['other_classes/0hhfOGkn8AU_000047_000057.mp4', 'other_classes']
# path_label_split: ['other_classes/0huCctby4jI_000001_000011.mp4', 'other_classes']
# path_label_split: ['other_classes/0IEf-piWfMU_000068_000078.mp4', 'other_classes']
# path_label_split: ['other_classes/0J_1N_Gl96U_000049_000059.mp4', 'other_classes']
# path_label_split: ['other_classes/0jFBHhjvbYs_000465_000475.mp4', 'other_classes']
# path_label_split: ['other_classes/0juaB_xZmOo_000010_000020.mp4', 'other_classes']
# path_label_split: ['other_classes/0Kdr4Ar9OVw_000532_000542.mp4', 'other_classes']
# path_label_split: ['other_classes/0KERPPNrMv8_000018_000028.mp4', 'other_classes']
# path_label_split: ['other_classes/0kzT1vUmVW0_000187_000197.mp4', 'other_classes']
# path_label_split: ['other_classes/0LlBKABZ5zo_000209_000219.mp4', 'other_classes']
# path_label_split: ['other_classes/0luQfCHdTUE_000032_000042.mp4', 'other_classes']
# path_label_split: ['other_classes/0LwWBmj4Qf4_000077_000087.mp4', 'other_classes']
# path_label_split: ['other_classes/0Mx1HtzxQOc_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0MyuaROu6jM_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0oH5zzWqVR4_000128_000138.mp4', 'other_classes']
# path_label_split: ['other_classes/0p0AvQmzG8Q_000001_000011.mp4', 'other_classes']
# path_label_split: ['other_classes/0QEd8H36Fic_000094_000104.mp4', 'other_classes']
# path_label_split: ['other_classes/0QmKHfYfovk_000052_000062.mp4', 'other_classes']
# path_label_split: ['other_classes/0RQg5WDhVKs_000001_000011.mp4', 'other_classes']
# path_label_split: ['other_classes/0RQg5WDhVKs_000018_000028.mp4', 'other_classes']
# path_label_split: ['other_classes/0RuzsmJMewM_000007_000017.mp4', 'other_classes']
# path_label_split: ['other_classes/0SBQpqgIw1c_000158_000168.mp4', 'other_classes']
# path_label_split: ['other_classes/0sXr00ihsYw_000026_000036.mp4', 'other_classes']
# path_label_split: ['other_classes/0VsKrnxwZ6o_000005_000015.mp4', 'other_classes']
# path_label_split: ['other_classes/0WgrxBcjLhQ_000003_000013.mp4', 'other_classes']
# path_label_split: ['other_classes/_-0WkCCy0MA_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/0WRxFOLhrak_000401_000411.mp4', 'other_classes']
# path_label_split: ['other_classes/0_wWIodklTc_000070_000080.mp4', 'other_classes']
# path_label_split: ['other_classes/0xoo3cByDYM_000031_000041.mp4', 'other_classes']
# path_label_split: ['other_classes/-0zGo1-PIjs_000022_000032.mp4', 'other_classes']
# path_label_split: ['other_classes/0ZXsAT5jWYg_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/10ZhoufZGRA_000020_000030.mp4', 'other_classes']
# path_label_split: ['other_classes/11WfYWXFS9M_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/14Lt68zdX9A_000003_000013.mp4', 'other_classes']
# path_label_split: ['other_classes/15mynloL3pI_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/161T0kEGI1I_000038_000048.mp4', 'other_classes']
# path_label_split: ['other_classes/1b29vhR4AeY_000004_000014.mp4', 'other_classes']
# path_label_split: ['other_classes/1bS7CDbz4T0_000036_000046.mp4', 'other_classes']
# path_label_split: ['other_classes/-1CDVqZHKbk_000005_000015.mp4', 'other_classes']
# path_label_split: ['other_classes/1Cd-YMpEIZ8_000010_000020.mp4', 'other_classes']
# path_label_split: ['other_classes/1dJW9_6zy5w_000002_000012.mp4', 'other_classes']
# path_label_split: ['other_classes/1dlqB2h6k9U_000004_000014.mp4', 'other_classes']
# path_label_split: ['other_classes/1Dz1FGJ1huE_000189_000199.mp4', 'other_classes']
# path_label_split: ['other_classes/1ehDWXzIGFU_000045_000055.mp4', 'other_classes']
# path_label_split: ['other_classes/1ei-0k9VJZQ_000005_000015.mp4', 'other_classes']
# path_label_split: ['other_classes/1elitRm1sK4_000026_000036.mp4', 'other_classes']
# path_label_split: ['other_classes/1exarhq0Tlg_000010_000020.mp4', 'other_classes']
# path_label_split: ['other_classes/1FskbWo7Quw_000002_000012.mp4', 'other_classes']
# path_label_split: ['other_classes/1GzkdwfQHVU_000063_000073.mp4', 'other_classes']
# path_label_split: ['other_classes/1-I3bZnxQIY_000047_000057.mp4', 'other_classes']
# path_label_split: ['other_classes/1IFyxzf-73E_000002_000012.mp4', 'other_classes']
# path_label_split: ['other_classes/1INhDm0d8xs_000004_000014.mp4', 'other_classes']
# path_label_split: ['other_classes/1IpcAIxLKug_000057_000067.mp4', 'other_classes']
# path_label_split: ['other_classes/1iqV0sUcGM4_000054_000064.mp4', 'other_classes']
# path_label_split: ['other_classes/1IYhIz6bNns_000020_000030.mp4', 'other_classes']
# path_label_split: ['other_classes/1ka7WgI87ig_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/1KYfbKjknvY_000006_000016.mp4', 'other_classes']
# path_label_split: ['other_classes/1Mcjbne7VHg_000028_000038.mp4', 'other_classes']
# ck3
# dataset loading [0/200]
# ck1
# ck1 : in
# ck2: into get_ucf101
# opening_refrigerator
# {'opening_refrigerator': 0}
# other_classes
# {'opening_refrigerator': 0, 'other_classes': 1}
# path_label_split: ['opening_refrigerator/yGImIMbbD-U_000073_000083.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/YjMJ_gIyzHo_000001_000011.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ylrz29qXl-E_000007_000017.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/yOYBwRnI9eE_000011_000021.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Y-RDfeG59ZU_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/YVneQITJRoI_000092_000102.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/YW7r5ZPMNP4_000036_000046.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/YwFwg4W4UT4_000059_000069.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/yZ6iD_L2buc_000059_000069.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/yzv3p6h1QiY_000050_000060.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Z1w8YWfRXa4_000289_000299.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/z302M6dzYOk_000221_000231.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Z3CVQ1HHZ_s_000051_000061.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Z87lJc_aFhk_000010_000020.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZBgOhtbukog_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZcNyWP8QFdk_000004_000014.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/zdhAt7m6e4w_000001_000011.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZejwCVdWZJM_000014_000024.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZF7_kRnAGW4_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/zF8prij6oe4_000013_000023.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZHSJ9Tkx-oc_000009_000019.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZkdzHJAp3MI_000054_000064.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZL_zje9lAe4_000007_000017.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/zmVMcMsh5U8_000021_000031.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Zpm4NtHxA1c_000018_000028.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/zQNO4IUFgvw_000092_000102.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/z-U_bcfCqsc_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/Zwb-oWgS6T0_000015_000025.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/ZYLJaAgln1k_000007_000017.mp4', 'opening_refrigerator']
# path_label_split: ['opening_refrigerator/zZREdVGf4PE_000000_000010.mp4', 'opening_refrigerator']
# path_label_split: ['other_classes/1Mcjbne7VHg_000028_000038.mp4', 'other_classes']
# path_label_split: ['other_classes/1mPn_Oy6ASc_000019_000029.mp4', 'other_classes']
# path_label_split: ['other_classes/1nVC27-FFAQ_000016_000026.mp4', 'other_classes']
# path_label_split: ['other_classes/1OCcvQ7Brk4_000004_000014.mp4', 'other_classes']
# path_label_split: ['other_classes/1PtBBXi4Wv8_000060_000070.mp4', 'other_classes']
# path_label_split: ['other_classes/1q9f-V33f4w_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/1qbl1aKu4OE_000020_000030.mp4', 'other_classes']
# path_label_split: ['other_classes/1QYCGc9cHRk_000066_000076.mp4', 'other_classes']
# path_label_split: ['other_classes/1r3vZxx56Wk_000004_000014.mp4', 'other_classes']
# path_label_split: ['other_classes/1WJfpZG-0PQ_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/1X0WDA4ZqME_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes/20WrKOA_nc8_000027_000037.mp4', 'other_classes']
# path_label_split: ['other_classes/22QR6jfbiNQ_000011_000021.mp4', 'other_classes']
# path_label_split: ['other_classes/26J5vCj90Z8_000017_000027.mp4', 'other_classes']
# path_label_split: ['other_classes/26ywvh5BXuE_000000_000010.mp4', 'other_classes']
# path_label_split: ['other_classes
# Epoch 25/30
# 19/20 [===========================>..] - ETA: 3s - loss: 1.0747 - acc: 0.5053Epoch 1/30
# 20/20 [==============================] - 77s 4s/step - loss: 1.0703 - acc: 0.5100 - val_loss: 0.7155 - val_acc: 0.6250
# Epoch 26/30
# 19/20 [===========================>..] - ETA: 2s - loss: 0.9988 - acc: 0.5895Epoch 1/30
# 20/20 [==============================] - 62s 3s/step - loss: 1.0066 - acc: 0.5800 - val_loss: 0.7233 - val_acc: 0.6042
# Epoch 27/30
# 19/20 [===========================>..] - ETA: 3s - loss: 0.9242 - acc: 0.5789Epoch 1/30
# 20/20 [==============================] - 91s 5s/step - loss: 0.8993 - acc: 0.5900 - val_loss: 0.7021 - val_acc: 0.6250
# Epoch 28/30
# 19/20 [===========================>..] - ETA: 2s - loss: 0.8927 - acc: 0.5737Epoch 1/30
# 20/20 [==============================] - 64s 3s/step - loss: 0.8931 - acc: 0.5650 - val_loss: 0.6863 - val_acc: 0.6667
# Epoch 29/30
# 19/20 [===========================>..] - ETA: 2s - loss: 0.9951 - acc: 0.5579Epoch 1/30
# 20/20 [==============================] - 63s 3s/step - loss: 0.9867 - acc: 0.5600 - val_loss: 0.6891 - val_acc: 0.6458
# Epoch 30/30
# 19/20 [===========================>..] - ETA: 2s - loss: 0.9458 - acc: 0.5158Epoch 1/30
# 20/20 [==============================] - 68s 3s/step - loss: 0.9216 - acc: 0.5300 - val_loss: 0.7565 - val_acc: 0.6458
# model fit done
# mbashat: saving model
# printking Keys in history
# loss
# acc
# val_loss
# val_acc
# end of code

# %% [markdown]
# **TEST_CELL**

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import multi_gpu_model
from model import nets
from model import slowfast
from opts import parse_opts
from utils import get_optimizer, SGDRScheduler_with_WarmUp, TrainPrint, PrintLearningRate, ParallelModelCheckpoint
from dataset.dataset import DataGenerator
class Args:
  root_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/slowfast-keras2Class/slowfast-keras'
  video_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref_jpg'
  #name_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/classInd.txt'
  name_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_2class_jpg/classInd.txt'
  train_list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/train.txt'
  val_list = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/test.txt'
  result_path = 'results'
  data_name = 'ntu'
  gpus = [0]
  log_dir = 'log'
  num_classes = 2
  crop_size = 224
  clip_len = 64
  short_side = [256, 320]
  n_samples_for_each_video = 1
  lr = 0.00001
  momentum = 0.9
  weight_decay = 1e-4
  lr_decay = 0.8
  cycle_length = 10
  multi_factor = 1.5
  warm_up_epoch = 5
  optimizer = 'SGD'
  batch_size = 1
  epochs = 30
  workers = 4
  network = 'resnet50'
  pretrained_weights = None
  test_videos_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref_jpg'
  test_list_path = '/content/drive/My Drive/Colab Notebooks/CSCE636/Data/data_clips_100_ref/test_final.txt'
from tensorflow.keras.layers import Layer, InputSpec
opt = Args()
# load model
model = tf.keras.models.load_model('SlowFast_refrigerator_2803.h5')
# summarize model.
#model.summary()
predict_data_generator = DataGenerator(opt.data_name, opt.test_videos_path, opt.test_list_path, opt.name_path, 
                                        'val', 1, opt.num_classes, False, opt.short_side, 
                                        opt.crop_size, opt.clip_len, opt.n_samples_for_each_video, to_fit=False)  
model_predicted = model.predict(predict_data_generator)
import numpy as np
print(np.argmax(model_predicted, axis=1))
